# %%
import pandas as pd
import numpy as np

# %%
cd Shopify
# Out:
# [Errno 2] No such file or directory: 'Shopify'
# /Users/franciszekruszkowski/Desktop/Shopify

# %%
df = pd.read_excel("2019 Winter Data Science Intern Challenge Data Set.xlsx")

# %%
df
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at
# 0    2017-03-13 12:36:56.190
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   shop_id         5000 non-null   int64
#  2   user_id         5000 non-null   int64
#  3   order_amount    5000 non-null   int64
#  4   total_items     5000 non-null   int64
#  5   payment_method  5000 non-null   object
#  6   created_at      5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 273.6+ KB

# %%
df = df.set_index("order_id")

# %%
df["price-per-shoes"] = df["order_amount"]/df["total_items"]

# %%
df["price-per-shoes"]
# Out:
# order_id
# 1       112.0
# 2        90.0
# 3       144.0
# 4       156.0
# 5       156.0
#         ...
# 4996    165.0
# 4997    117.0
# 4998    117.0
# 4999    177.0
# 5000    144.0
# Name: price-per-shoes, Length: 5000, dtype: float64

# %%
df
# Out:
#           shop_id  user_id  order_amount  total_items payment_method  \
# order_id
# 1              53      746           224            2           cash
# 2              92      925            90            1           cash
# 3              44      861           144            1           cash
# 4              18      935           156            1    credit_card
# 5              18      883           156            1    credit_card
# ...           ...      ...           ...          ...            ...
# 4996           73      993           330            2          debit
# 4997           48      789           234            2           cash
# 4998           56      867           351            3           cash
# 4999           60      825           354            2    credit_card
# 5000           44      734           288            2          debit
#
#                       created_at  price-per-shoes
# order_id
# 1        2017-03-13 12:36:56.190            112.0
# ...

# %%
df["order_amount"].mean()
# Out:
# 3145.128

# %%
df[df["order_amount"]==df["order_amount"].max()]
# Out:
#           shop_id  user_id  order_amount  total_items payment_method  \
# order_id
# 16             42      607        704000         2000    credit_card
# 61             42      607        704000         2000    credit_card
# 521            42      607        704000         2000    credit_card
# 1105           42      607        704000         2000    credit_card
# 1363           42      607        704000         2000    credit_card
# 1437           42      607        704000         2000    credit_card
# 1563           42      607        704000         2000    credit_card
# 1603           42      607        704000         2000    credit_card
# 2154           42      607        704000         2000    credit_card
# 2298           42      607        704000         2000    credit_card
# 2836           42      607        704000         2000    credit_card
# 2970           42      607        704000         2000    credit_card
# ...

# %%
df["price-per-shoes"].mean()
# Out:
# 387.7428
